# %%
import numpy as np
import pandas as pd
import datetime as dt
from datascience import *
# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')
import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)

# %% [markdown]
# Find the number of seconds in June

# %%
number_seconds_june=60*60*24*30

# %%
number_seconds_june
# Out:
# 2592000

# %% [markdown]
# Find the time elapsed between 1 June at noon and 14 aug at 9:30

# %%
first_date=dt.datetime(2018,8,14,9,30,0)
second_date=dt.datetime(2018,6,1,12,0,0)

# %%
abs((second_date-first_date).total_seconds())
# Out:
# 6384600.0

# %% [markdown]
# Import World_Population.csv

# %%
world_pop_data=pd.read_csv("world_population.csv")

# %%
print(world_pop_data)
# Out:
#     Population
# 0   2557628654
# 1   2594939877
# 2   2636772306
# 3   2682053389
# 4   2730228104
# 5   2782098943
# 6   2835299673
# 7   2891349717
# 8   2948137248
# 9   3000716593
# 10  3043001508
# 11  3083966929
# 12  3140093217
# 13  3209827882
# 14  3281201306
# 15  3350425793
# 16  3420677923
# 17  3490333715
# 18  3562313822
# 19  3637159050
# 20  3712697742
# 21  3790326948
# 22  3866568653
# 23  3942096442
# 24  4016608813
# 25  4089083233
# 26  4160185010
# 27  4232084578
# 28  4304105753
# 29  4379013942
# ..         ...
# 36  4940571232
# 37  5027200492
# 38  5114557167
# 39  5201440110
# 40  5288955934
# 41  5371585922
# 42  5456136278
# 43  5538268316
# 44  5618682132
# 45  5699202985
# 46  5779440593
# 47  5857972543
# 48  5935213248
# 49  6012074922
# 50  6088571383
# 51  6165219247
# 52  6242016348
# 53  6318590956
# 54  6395699509
# 55  6473044732
# 56  6551263534
# 57  6629913759
# 58  6709049780
# 59  6788214394
# 60  6866332358
# 61  6944055583
# ...

# %%
pop_2015 = world_pop_data.iloc[65]
pop_2015
# Out:
# Population    7256490011
# Name: 65, dtype: int64

# %%
pop_1950 = world_pop_data.iloc[0]

# %%
pop1950to2015=pop_2015-pop_1950

# %%
pop1950to2015
# Out:
# Population    4698861357
# dtype: int64

# %% [markdown]
# Find the average population growth between 1950 and 2015

# %%
average_growth=(pop_2015/pop_1950)**(1/65)

# %%
average_growth=(average_growth-1)

# %%
average_growth
# Out:
# Population    0.016173
# dtype: float64

# %% [markdown]
# Load titanic data set

# %%
URL="https://raw.githubusercontent.com/oikobill/Kaggle/master/Titanic/data/train.csv"

# %%
titanic_data=pd.read_csv(URL)

# %%
titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %% [markdown]
# Relabel Pclass to Passenger_Class

# %%
titanic_data.columns.values[2]='Passenger_Class'

# %%
titanic_data
# Out:
#      PassengerId  Survived  Passenger_Class  \
# 0              1         0                3
# 1              2         1                1
# 2              3         1                3
# 3              4         1                1
# 4              5         0                3
# 5              6         0                3
# 6              7         0                1
# 7              8         0                3
# 8              9         1                3
# 9             10         1                2
# 10            11         1                3
# 11            12         1                1
# 12            13         0                3
# 13            14         0                3
# 14            15         0                3
# 15            16         1                2
# 16            17         0                3
# 17            18         1                2
# 18            19         0                3
# 19            20         1                3
# ...

# %% [markdown]
# Create new column family_size that adds number of siblings and spouses

# %%
titanic_data["family_size"]=titanic_data["SibSp"]+titanic_data["Parch"]

# %%
titanic_data
# Out:
#      PassengerId  Survived  Passenger_Class  \
# 0              1         0                3
# 1              2         1                1
# 2              3         1                3
# 3              4         1                1
# 4              5         0                3
# 5              6         0                3
# 6              7         0                1
# 7              8         0                3
# 8              9         1                3
# 9             10         1                2
# 10            11         1                3
# 11            12         1                1
# 12            13         0                3
# 13            14         0                3
# 14            15         0                3
# 15            16         1                2
# 16            17         0                3
# 17            18         1                2
# 18            19         0                3
# 19            20         1                3
# ...

# %%
titanic_data2=titanic_data.groupby("Passenger_Class").Passenger_Class.count()

# %%
titanic_data2
# Out:
# Passenger_Class
# 1    216
# 2    184
# 3    491
# Name: Passenger_Class, dtype: int64

# %% [markdown]
# Bar Plot of number of passengers by passenger class

# %%
titanic_data2.plot(kind="bar")

# %% [markdown]
# Find the top 5 younges and oldest passengers

# %%
titanic_data.sort_values("Age", ascending=[True]).head(5)
# Out:
#      PassengerId  Survived  Passenger_Class                             Name  \
# 803          804         1                3  Thomas, Master. Assad Alexander
# 755          756         1                2        Hamalainen, Master. Viljo
# 644          645         1                3           Baclini, Miss. Eugenie
# 469          470         1                3    Baclini, Miss. Helene Barbara
# 78            79         1                2    Caldwell, Master. Alden Gates
#
#         Sex   Age  SibSp  Parch  Ticket     Fare Cabin Embarked  family_size
# 803    male  0.42      0      1    2625   8.5167   NaN        C            1
# 755    male  0.67      1      1  250649  14.5000   NaN        S            2
# 644  female  0.75      2      1    2666  19.2583   NaN        C            3
# 469  female  0.75      2      1    2666  19.2583   NaN        C            3
# 78     male  0.83      0      2  248738  29.0000   NaN        S            2

# %% [markdown]
# Youngest 5

# %%
titanic_data.sort_values("Age", ascending=[False]).head(5)
# Out:
#      PassengerId  Survived  Passenger_Class  \
# 630          631         1                1
# 851          852         0                3
# 493          494         0                1
# 96            97         0                1
# 116          117         0                3
#
#                                      Name   Sex   Age  SibSp  Parch    Ticket  \
# 630  Barkworth, Mr. Algernon Henry Wilson  male  80.0      0      0     27042
# 851                   Svensson, Mr. Johan  male  74.0      0      0    347060
# 493               Artagaveytia, Mr. Ramon  male  71.0      0      0  PC 17609
# 96              Goldschmidt, Mr. George B  male  71.0      0      0  PC 17754
# 116                  Connors, Mr. Patrick  male  70.5      0      0    370369
#
#         Fare Cabin Embarked  family_size
# 630  30.0000   A23        S            0
# 851   7.7750   NaN        S            0
# 493  49.5042   NaN        C            0
# 96   34.6542    A5        C            0
# ...

# %% [markdown]
# Oldest 5

# %% [markdown]
# With the method I used NaN values where sorted to the bottom at all times, to remove these values the following code works:

# %%
titanic_data=titanic_data[~titanic_data["Age"].isin(["NaN"])]

# %%
titanic_data
# Out:
#      PassengerId  Survived  Passenger_Class  \
# 0              1         0                3
# 1              2         1                1
# 2              3         1                3
# 3              4         1                1
# 4              5         0                3
# 6              7         0                1
# 7              8         0                3
# 8              9         1                3
# 9             10         1                2
# 10            11         1                3
# 11            12         1                1
# 12            13         0                3
# 13            14         0                3
# 14            15         0                3
# 15            16         1                2
# 16            17         0                3
# 18            19         0                3
# 20            21         0                2
# 21            22         1                2
# 22            23         1                3
# ...

# %%
titanic_data3=titanic_data.iloc[:,1:3]

# %% [markdown]
# find the survival rate based on passenger class

# %%
titanic_data3.groupby("Passenger_Class").Survived.mean()
# Out:
# Passenger_Class
# 1    0.655914
# 2    0.479769
# 3    0.239437
# Name: Survived, dtype: float64

# %% [markdown]
# how many males compared to females where theere on the titanic

# %%
titanic4=titanic_data.groupby("Sex").PassengerId.count()

# %%
titanic4
# Out:
# Sex
# female    261
# male      453
# Name: PassengerId, dtype: int64

# %% [markdown]
# What was the difference in survival rate for males to females

# %%
titanic5=titanic_data.groupby("Sex").Survived.mean()

# %%
titanic5
# Out:
# Sex
# female    0.754789
# male      0.205298
# Name: Survived, dtype: float64
