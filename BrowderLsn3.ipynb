# %%
import numpy as np
import pandas as pd
import datetime as dt
from datascience import *
# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')
import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)

# %%
number_seconds_june=60*60*24*30

# %%
number_seconds_june
# Out:
# 2592000

# %%
first_date=dt.datetime(2018,8,14,9,30,0)
second_date=dt.datetime(2018,6,1,12,0,0)

# %%
abs((second_date-first_date).total_seconds())
# Out:
# 6384600.0

# %%
world_pop_data=pd.read_csv("C:/Users/C19Milo.Browder/Desktop/Math_377/Data/world_population.csv")

# %%
print(world_pop_data)
# Out:
#     Population
# 0   2557628654
# 1   2594939877
# 2   2636772306
# 3   2682053389
# 4   2730228104
# 5   2782098943
# 6   2835299673
# 7   2891349717
# 8   2948137248
# 9   3000716593
# 10  3043001508
# 11  3083966929
# 12  3140093217
# 13  3209827882
# 14  3281201306
# 15  3350425793
# 16  3420677923
# 17  3490333715
# 18  3562313822
# 19  3637159050
# 20  3712697742
# 21  3790326948
# 22  3866568653
# 23  3942096442
# 24  4016608813
# 25  4089083233
# 26  4160185010
# 27  4232084578
# 28  4304105753
# 29  4379013942
# ..         ...
# 36  4940571232
# 37  5027200492
# 38  5114557167
# 39  5201440110
# 40  5288955934
# 41  5371585922
# 42  5456136278
# 43  5538268316
# 44  5618682132
# 45  5699202985
# 46  5779440593
# 47  5857972543
# 48  5935213248
# 49  6012074922
# 50  6088571383
# 51  6165219247
# 52  6242016348
# 53  6318590956
# 54  6395699509
# 55  6473044732
# 56  6551263534
# 57  6629913759
# 58  6709049780
# 59  6788214394
# 60  6866332358
# 61  6944055583
# ...

# %%
pop_2015 = world_pop_data.iloc[65]
pop_2015
# Out:
# Population    7256490011
# Name: 65, dtype: int64

# %%
pop_1950 = world_pop_data.iloc[0]

# %%
pop1950to2015=pop_2015-pop_1950

# %%
pop1950to2015
# Out:
# Population    4698861357
# dtype: int64

# %%
average_growth=(pop_2015/pop_1950)**(1/65)

# %%
average_growth=(average_growth-1)

# %%
average_growth
# Out:
# Population    0.016173
# dtype: float64

# %%
URL="https://raw.githubusercontent.com/oikobill/Kaggle/master/Titanic/data/train.csv"

# %%
titanic_data=pd.read_csv(URL)

# %%
titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
titanic_data.columns.values[4]='Passenger_Class'

# %%
titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
len(titanic_data.columns)
# Out:
# 12

# %%
titanic_data.columns.get_loc("SibSp")
# Out:
# 6

# %%
titanic_data.columns.get_loc("Parch")
# Out:
# 7

# %%
def f(x,y):
    return x+y

# %%
titanic_data["family_size"]=titanic_data["SibSp"]+titanic_data["Parch"]

# %%
titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
titanic_data.plot(x="Passenger_Class",y="family_size",kind="bar")

# %%
titanic_data.groupby("Passenger_Class")["family_size"].plot(legend=True)
# Out:
# Passenger_Class
# female    AxesSubplot(0.08,0.07;0.87x0.81)
# male      AxesSubplot(0.08,0.07;0.87x0.81)
# Name: family_size, dtype: object

# %%
titanic_data.groupby("Passenger_Class").plot(legend=True)
# Out:
# Passenger_Class
# female    AxesSubplot(0.08,0.07;0.87x0.81)
# male      AxesSubplot(0.08,0.07;0.87x0.81)
# dtype: object

# %%
for title, group in titanic_data.groupby("Passenger_Class"):
    group.plot(x="Passenger_Class", y="family_size", title=title)

# %%
titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
titanic_data.sort_values("Age", ascending=[False])
# Out:
#      PassengerId  Survived  Pclass  \
# 630          631         1       1
# 851          852         0       3
# 493          494         0       1
# 96            97         0       1
# 116          117         0       3
# 672          673         0       2
# 745          746         0       1
# 33            34         0       2
# 54            55         0       1
# 280          281         0       3
# 456          457         0       1
# 438          439         0       1
# 545          546         0       1
# 275          276         1       1
# 483          484         1       3
# 570          571         1       2
# 252          253         0       1
# 829          830         1       1
# 555          556         0       1
# 625          626         0       1
# 326          327         0       3
# 170          171         0       1
# 684          685         0       2
# 694          695         0       1
# 587          588         1       1
# ...

# %%
titanic_data.sort_values("Age", ascending=[True])
# Out:
#      PassengerId  Survived  Pclass  \
# 803          804         1       3
# 755          756         1       2
# 644          645         1       3
# 469          470         1       3
# 78            79         1       2
# 831          832         1       2
# 305          306         1       1
# 827          828         1       2
# 381          382         1       3
# 164          165         0       3
# 183          184         1       2
# 386          387         0       3
# 172          173         1       3
# 788          789         1       3
# 642          643         0       3
# 7              8         0       3
# 530          531         1       2
# 297          298         0       1
# 824          825         0       3
# 205          206         0       3
# 119          120         0       3
# 340          341         1       2
# 479          480         1       3
# 16            17         0       3
# 348          349         1       3
# ...

# %%
titanic_data[~titanic_data["Age"].isin(["NaN"])]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 18            19         0       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# 25            26         1       3
# 27            28         0       1
# 30            31         0       1
# ...
